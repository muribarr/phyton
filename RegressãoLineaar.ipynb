# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

# %%
df = pd.read_csv('./Documents/murilo/03_Regressão Linear/03_Regressão Linear/1_Regressao_Linear_Simples/base_funcionarios_v1.csv, sep=';', 'index_col='id')
# Out:
#   Cell In[13], line 1
#     df = pd.read_csv('./Documents/murilo/03_Regressão Linear/03_Regressão Linear/1_Regressao_Linear_Simples/base_funcionarios_v1.csv, sep=';', 'index_col='id')
#                                                                                                                                            ^
# SyntaxError: invalid syntax

# %%
df

# %%
df.shape

# %%
df.tail()

# %%
df.info()

# %%
df.describe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.describe
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# Salario               float64
# Anos_Educ_Superior      int64
# dtype: object

# %%
sns.scatterplot(x=df['Anos_Educ_Superior'],
                y=df['Salario'])
# Out:
# <Axes: xlabel='Anos_Educ_Superior', ylabel='Salario'>

# %%
fig = plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),
            cmap='RdBu_r',
            vmin=-1, vmax=1,
            annot=True
)
# Out:
# <Axes: >

# %%
y = df['Salario']

df['intercepto'] = 1
x = df[['intercepto',
        'Anos_Educ_Superior']
]

# %%
modelo = sm.OLS(y,x)
resultado = modelo.fit()

# %%
print(resultado.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Salario   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.595
# Method:                 Least Squares   F-statistic:                     67.03
# Date:                Fri, 07 Jun 2024   Prob (F-statistic):           2.18e-10
# Time:                        15:18:01   Log-Likelihood:                -391.36
# No. Observations:                  46   AIC:                             786.7
# Df Residuals:                      44   BIC:                             790.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercepto          4301.7990    372.608     11.545      0.000    3550.857    5052.741
# ...

# %%
sns.regplot(x=df['Anos_Educ_Superior'],
            y=df['Salario'], ci=None);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.regplot(x=df['Anos_Educ_Superior'],
#       2             y=df['Salario'], ci=None)
#
# NameError: name 'sns' is not defined
